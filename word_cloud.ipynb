# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_bersih_neg.csv")
df.head()
# Out:
#                     url                                               text  \
# 0   https://pornhub.com  spicevid uviu sexual well insight site shop tr...
# 1   https://xvideos.com  welcom xvideoscom pleas select prefer version ...
# 2  https://xhamster.com  nl login sign free video live sex categori por...
# 3   https://redtube.com  cooki choic use cooki similar technolog necess...
# 4      https://xnxx.com  welcom xnxxcom pleas select prefer version usa...
#
#       status
# 0  berbahaya
# 1  berbahaya
# 2  berbahaya
# 3  berbahaya
# 4  berbahaya

# %%
tes = df['text'].to_list()
# Menggabungkan semua kata dalam kolom tweet
all_words = ' '.join(tes)

# Membuat objek WordCloud
wordcloud = WordCloud(width=800, height=400, collocations=False, background_color='white').generate(all_words)

# Menampilkan Word Cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud Kata Mayoritas dalam Tweet setelah di preprocessing')
plt.show()
